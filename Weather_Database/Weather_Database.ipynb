# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the citipy module.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combination
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c69d4102d300cea33c9753ae66a20466

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alice springs
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | leh
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | krasnyy chikoy
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | san cristobal
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | erenhot
# Processing Record 11 of Set 1 | mayumba
# Processing Record 12 of Set 1 | huainan
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | la romana
# Processing Record 19 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | griffith
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | progreso
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 1 | high rock
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | general roca
# Processing Record 42 of Set 1 | westport
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | port hawkesbury
# Processing Record 45 of Set 1 | prince rupert
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | hwange
# Processing Record 48 of Set 1 | portland
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | ishim
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | havre-saint-pierre
# Processing Record 3 of Set 2 | kulu
# Processing Record 4 of Set 2 | japura
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | beringovskiy
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | pingliang
# Processing Record 11 of Set 2 | tuatapere
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | rio grande
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | verona
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | souillac
# Processing Record 21 of Set 2 | watsa
# Processing Record 22 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 2 | vestmannaeyjar
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | coihaique
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | nizhniy tsasuchey
# Processing Record 28 of Set 2 | sompeta
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | vostok
# Processing Record 31 of Set 2 | maryville
# Processing Record 32 of Set 2 | siutu
# City not found. Skipping...
# Processing Record 33 of Set 2 | pathein
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | saint-francois
# Processing Record 39 of Set 2 | baracoa
# Processing Record 40 of Set 2 | dhekiajuli
# Processing Record 41 of Set 2 | haines junction
# Processing Record 42 of Set 2 | zhezkazgan
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | koundara
# Processing Record 49 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 2 | havoysund
# Processing Record 1 of Set 3 | bulancak
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | khovu-aksy
# Processing Record 8 of Set 3 | roma
# Processing Record 9 of Set 3 | coquimbo
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | maragogi
# Processing Record 16 of Set 3 | aklavik
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | shingu
# Processing Record 19 of Set 3 | ketchikan
# Processing Record 20 of Set 3 | kaitangata
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | follonica
# Processing Record 23 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | angoche
# Processing Record 26 of Set 3 | mikhaylovskoye
# Processing Record 27 of Set 3 | torbay
# Processing Record 28 of Set 3 | mataura
# Processing Record 29 of Set 3 | popondetta
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | cooma
# Processing Record 33 of Set 3 | tezu
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | lahij
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | paamiut
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | morant bay
# Processing Record 41 of Set 3 | cayenne
# Processing Record 42 of Set 3 | altay
# Processing Record 43 of Set 3 | vrsac
# Processing Record 44 of Set 3 | kajaani
# Processing Record 45 of Set 3 | sendhwa
# Processing Record 46 of Set 3 | biak
# Processing Record 47 of Set 3 | puerto leguizamo
# Processing Record 48 of Set 3 | ahipara
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | karachi
# Processing Record 2 of Set 4 | umm kaddadah
# Processing Record 3 of Set 4 | cerrito
# Processing Record 4 of Set 4 | qaqortoq
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | nago
# Processing Record 7 of Set 4 | palmer
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 4 | takaungu
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | charters towers
# Processing Record 13 of Set 4 | entre rios
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | wuning
# Processing Record 16 of Set 4 | bridlington
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | oktyabrskoye
# Processing Record 19 of Set 4 | honningsvag
# Processing Record 20 of Set 4 | san rafael
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | kidal
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | itaituba
# Processing Record 26 of Set 4 | marsa matruh
# Processing Record 27 of Set 4 | kieta
# Processing Record 28 of Set 4 | kitui
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | taksimo
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | yeppoon
# Processing Record 33 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 4 | bilma
# Processing Record 35 of Set 4 | berdigestyakh
# Processing Record 36 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | kodiak
# Processing Record 39 of Set 4 | tomatlan
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | fort smith
# Processing Record 43 of Set 4 | dunedin
# Processing Record 44 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | chumikan
# Processing Record 47 of Set 4 | lajas
# Processing Record 48 of Set 4 | jambi
# Processing Record 49 of Set 4 | gornopravdinsk
# Processing Record 50 of Set 4 | along
# Processing Record 1 of Set 5 | katsuura
# Processing Record 2 of Set 5 | baoying
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | caravelas
# Processing Record 5 of Set 5 | craig
# Processing Record 6 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | port-gentil
# Processing Record 9 of Set 5 | tiznit
# Processing Record 10 of Set 5 | pyaozerskiy
# Processing Record 11 of Set 5 | ponta delgada
# Processing Record 12 of Set 5 | chapais
# Processing Record 13 of Set 5 | ngunguru
# Processing Record 14 of Set 5 | fairbanks
# Processing Record 15 of Set 5 | northam
# Processing Record 16 of Set 5 | nyagan
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | komsomolskiy
# Processing Record 19 of Set 5 | santa fe
# Processing Record 20 of Set 5 | honolulu
# Processing Record 21 of Set 5 | antsirabe
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | chuy
# Processing Record 26 of Set 5 | yumen
# Processing Record 27 of Set 5 | bronkhorstspruit
# Processing Record 28 of Set 5 | meadow lake
# Processing Record 29 of Set 5 | alexandria
# Processing Record 30 of Set 5 | gangawati
# Processing Record 31 of Set 5 | port alfred
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | dustlik
# Processing Record 34 of Set 5 | kaeo
# Processing Record 35 of Set 5 | mogadishu
# Processing Record 36 of Set 5 | ilulissat
# Processing Record 37 of Set 5 | shangzhi
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | panama city
# Processing Record 40 of Set 5 | kamsack
# Processing Record 41 of Set 5 | ginir
# Processing Record 42 of Set 5 | ola
# Processing Record 43 of Set 5 | fruitvale
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | hamamatsu
# Processing Record 46 of Set 5 | kota belud
# Processing Record 47 of Set 5 | pangkalanbuun
# Processing Record 48 of Set 5 | ribas do rio pardo
# Processing Record 49 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 5 | dikson
# Processing Record 1 of Set 6 | quatre cocos
# Processing Record 2 of Set 6 | saskylakh
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | bima
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | ambon
# Processing Record 7 of Set 6 | hokitika
# Processing Record 8 of Set 6 | sabang
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | buala
# Processing Record 11 of Set 6 | vigrestad
# Processing Record 12 of Set 6 | carndonagh
# Processing Record 13 of Set 6 | keffi
# Processing Record 14 of Set 6 | ciudad guayana
# Processing Record 15 of Set 6 | nuevo progreso
# Processing Record 16 of Set 6 | agadez
# Processing Record 17 of Set 6 | weatherford
# Processing Record 18 of Set 6 | cherskiy
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | ponta do sol
# Processing Record 22 of Set 6 | bardsir
# Processing Record 23 of Set 6 | doha
# Processing Record 24 of Set 6 | puerto escondido
# Processing Record 25 of Set 6 | kaitong
# Processing Record 26 of Set 6 | marzuq
# Processing Record 27 of Set 6 | khasan
# Processing Record 28 of Set 6 | brisbane
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | piacabucu
# Processing Record 31 of Set 6 | araouane
# Processing Record 32 of Set 6 | san benito abad
# Processing Record 33 of Set 6 | sao felix do xingu
# Processing Record 34 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 6 | muroto
# Processing Record 36 of Set 6 | teguldet
# Processing Record 37 of Set 6 | saint-augustin
# Processing Record 38 of Set 6 | litovko
# Processing Record 39 of Set 6 | surt
# Processing Record 40 of Set 6 | alassio
# Processing Record 41 of Set 6 | norsup
# Processing Record 42 of Set 6 | pevek
# Processing Record 43 of Set 6 | medea
# Processing Record 44 of Set 6 | east london
# Processing Record 45 of Set 6 | oktyabrskiy
# Processing Record 46 of Set 6 | kattivakkam
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | channel-port aux basques
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | keuruu
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | grindavik
# Processing Record 3 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 7 | batagay-alyta
# Processing Record 5 of Set 7 | macamic
# Processing Record 6 of Set 7 | faro
# Processing Record 7 of Set 7 | wangou
# Processing Record 8 of Set 7 | nehe
# Processing Record 9 of Set 7 | lander
# Processing Record 10 of Set 7 | tasiilaq
# Processing Record 11 of Set 7 | ludvika
# Processing Record 12 of Set 7 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 13 of Set 7 | kuldur
# Processing Record 14 of Set 7 | gamba
# Processing Record 15 of Set 7 | vanimo
# Processing Record 16 of Set 7 | necochea
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | zhaozhou
# Processing Record 19 of Set 7 | orlik
# Processing Record 20 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 7 | tiksi
# Processing Record 22 of Set 7 | chulman
# Processing Record 23 of Set 7 | hukuntsi
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | san andres
# Processing Record 26 of Set 7 | aksu
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | viesca
# Processing Record 29 of Set 7 | imbituba
# Processing Record 30 of Set 7 | aguimes
# Processing Record 31 of Set 7 | shenzhen
# Processing Record 32 of Set 7 | leningradskiy
# Processing Record 33 of Set 7 | barra do garcas
# Processing Record 34 of Set 7 | neryungri
# Processing Record 35 of Set 7 | kutum
# Processing Record 36 of Set 7 | mecca
# Processing Record 37 of Set 7 | huesca
# Processing Record 38 of Set 7 | kijang
# Processing Record 39 of Set 7 | bodden town
# Processing Record 40 of Set 7 | eidsvag
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | noumea
# Processing Record 43 of Set 7 | gigmoto
# Processing Record 44 of Set 7 | flin flon
# Processing Record 45 of Set 7 | tangjiazhuang
# Processing Record 46 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | ukiah
# Processing Record 49 of Set 7 | shitanjing
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | north bay
# Processing Record 2 of Set 8 | taoudenni
# Processing Record 3 of Set 8 | linxia
# Processing Record 4 of Set 8 | vanavara
# Processing Record 5 of Set 8 | dogondoutchi
# Processing Record 6 of Set 8 | vidim
# Processing Record 7 of Set 8 | fort nelson
# Processing Record 8 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 8 | ganzhou
# Processing Record 10 of Set 8 | tabas
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | koslan
# Processing Record 13 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 8 | teya
# Processing Record 15 of Set 8 | lindas
# Processing Record 16 of Set 8 | portobelo
# Processing Record 17 of Set 8 | batemans bay
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | broome
# Processing Record 20 of Set 8 | llanes
# Processing Record 21 of Set 8 | westerland
# Processing Record 22 of Set 8 | lompoc
# Processing Record 23 of Set 8 | ulaanbaatar
# Processing Record 24 of Set 8 | tautira
# Processing Record 25 of Set 8 | mabaruma
# Processing Record 26 of Set 8 | xinzhou
# Processing Record 27 of Set 8 | krasnaya poyma
# Processing Record 28 of Set 8 | curvelo
# Processing Record 29 of Set 8 | magaria
# Processing Record 30 of Set 8 | naliya
# Processing Record 31 of Set 8 | deputatskiy
# Processing Record 32 of Set 8 | moussoro
# Processing Record 33 of Set 8 | kendari
# Processing Record 34 of Set 8 | kudahuvadhoo
# Processing Record 35 of Set 8 | sangmelima
# Processing Record 36 of Set 8 | dudinka
# Processing Record 37 of Set 8 | riyadh
# Processing Record 38 of Set 8 | veraval
# Processing Record 39 of Set 8 | gat
# Processing Record 40 of Set 8 | melfort
# Processing Record 41 of Set 8 | balaipungut
# Processing Record 42 of Set 8 | ewa beach
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | ransang
# Processing Record 45 of Set 8 | damaturu
# Processing Record 46 of Set 8 | bergen
# Processing Record 47 of Set 8 | kupang
# Processing Record 48 of Set 8 | muromtsevo
# Processing Record 49 of Set 8 | pishin
# Processing Record 50 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 9 | omsukchan
# Processing Record 2 of Set 9 | poya
# Processing Record 3 of Set 9 | vardo
# Processing Record 4 of Set 9 | mollendo
# Processing Record 5 of Set 9 | hals
# Processing Record 6 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | harur
# Processing Record 8 of Set 9 | tefe
# Processing Record 9 of Set 9 | coruripe
# Processing Record 10 of Set 9 | izberbash
# Processing Record 11 of Set 9 | rurrenabaque
# Processing Record 12 of Set 9 | airai
# Processing Record 13 of Set 9 | kautokeino
# Processing Record 14 of Set 9 | gouyave
# Processing Record 15 of Set 9 | bonavista
# Processing Record 16 of Set 9 | baruun-urt
# Processing Record 17 of Set 9 | espanola
# Processing Record 18 of Set 9 | usinsk
# Processing Record 19 of Set 9 | youhao
# Processing Record 20 of Set 9 | tabuk
# Processing Record 21 of Set 9 | tianpeng
# Processing Record 22 of Set 9 | vincennes
# Processing Record 23 of Set 9 | sistranda
# Processing Record 24 of Set 9 | tigil
# Processing Record 25 of Set 9 | quzhou
# Processing Record 26 of Set 9 | ucluelet
# Processing Record 27 of Set 9 | coracora
# Processing Record 28 of Set 9 | karpathos
# Processing Record 29 of Set 9 | san jeronimo
# Processing Record 30 of Set 9 | antalaha
# Processing Record 31 of Set 9 | kushmurun
# Processing Record 32 of Set 9 | ugoofaaru
# Processing Record 33 of Set 9 | barao de melgaco
# Processing Record 34 of Set 9 | ojinaga
# Processing Record 35 of Set 9 | iralaya
# Processing Record 36 of Set 9 | whitehaven
# Processing Record 37 of Set 9 | markova
# Processing Record 38 of Set 9 | longyearbyen
# Processing Record 39 of Set 9 | isla vista
# Processing Record 40 of Set 9 | samana
# Processing Record 41 of Set 9 | los llanos de aridane
# Processing Record 42 of Set 9 | touros
# Processing Record 43 of Set 9 | krasnoborsk
# Processing Record 44 of Set 9 | cuamba
# Processing Record 45 of Set 9 | beyla
# Processing Record 46 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 47 of Set 9 | puerto cortes
# City not found. Skipping...
# Processing Record 48 of Set 9 | sisimiut
# Processing Record 49 of Set 9 | sao joao da barra
# Processing Record 50 of Set 9 | laela
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 10 | turukhansk
# Processing Record 4 of Set 10 | nieuw amsterdam
# Processing Record 5 of Set 10 | cochabamba
# Processing Record 6 of Set 10 | kaihua
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | altagracia de orituco
# Processing Record 9 of Set 10 | jumla
# Processing Record 10 of Set 10 | itaqui
# Processing Record 11 of Set 10 | baykit
# Processing Record 12 of Set 10 | inhambane
# Processing Record 13 of Set 10 | kurilsk
# Processing Record 14 of Set 10 | abyek
# Processing Record 15 of Set 10 | san quintin
# Processing Record 16 of Set 10 | asyut
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | bundaberg
# Processing Record 19 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 10 | turbat
# Processing Record 21 of Set 10 | konza
# Processing Record 22 of Set 10 | el tocuyo
# Processing Record 23 of Set 10 | benghazi
# Processing Record 24 of Set 10 | moerai
# Processing Record 25 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 10 | kaifeng
# Processing Record 27 of Set 10 | awbari
# Processing Record 28 of Set 10 | prachuap khiri khan
# Processing Record 29 of Set 10 | illela
# Processing Record 30 of Set 10 | geraldton
# Processing Record 31 of Set 10 | mangla
# Processing Record 32 of Set 10 | meulaboh
# Processing Record 33 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 10 | bambui
# Processing Record 35 of Set 10 | venezuela
# Processing Record 36 of Set 10 | goroka
# Processing Record 37 of Set 10 | kalmar
# Processing Record 38 of Set 10 | mariakani
# Processing Record 39 of Set 10 | charlestown
# Processing Record 40 of Set 10 | kindu
# Processing Record 41 of Set 10 | pemba
# Processing Record 42 of Set 10 | kurchum
# Processing Record 43 of Set 10 | korla
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | akyab
# Processing Record 47 of Set 10 | port hardy
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | wajid
# Processing Record 50 of Set 10 | kiama
# Processing Record 1 of Set 11 | nioro
# Processing Record 2 of Set 11 | ambulu
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | thinadhoo
# Processing Record 5 of Set 11 | derzhavinsk
# Processing Record 6 of Set 11 | galesong
# Processing Record 7 of Set 11 | monmouth
# Processing Record 8 of Set 11 | betare oya
# Processing Record 9 of Set 11 | ruteng
# Processing Record 10 of Set 11 | gijon
# Processing Record 11 of Set 11 | srednekolymsk
# Processing Record 12 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 13 of Set 11 | mackay
# Processing Record 14 of Set 11 | dingle
# Processing Record 15 of Set 11 | jinji
# Processing Record 16 of Set 11 | djibo
# Processing Record 17 of Set 11 | kuusamo
# Processing Record 18 of Set 11 | preston
# Processing Record 19 of Set 11 | sirjan
# Processing Record 20 of Set 11 | nisko
# Processing Record 21 of Set 11 | chateauroux
# Processing Record 22 of Set 11 | yarmouth
# Processing Record 23 of Set 11 | bolshaya murta
# City not found. Skipping...
# Processing Record 24 of Set 11 | ringebu
# Processing Record 25 of Set 11 | adana
# Processing Record 26 of Set 11 | muborak
# Processing Record 27 of Set 11 | tombouctou
# Processing Record 28 of Set 11 | husavik
# Processing Record 29 of Set 11 | biloela
# Processing Record 30 of Set 11 | mogok
# Processing Record 31 of Set 11 | mersing
# Processing Record 32 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 11 | narsaq
# Processing Record 34 of Set 11 | andenes
# Processing Record 35 of Set 11 | tadine
# Processing Record 36 of Set 11 | miri
# Processing Record 37 of Set 11 | itupiranga
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | zeya
# Processing Record 40 of Set 11 | zaysan
# Processing Record 41 of Set 11 | lakes entrance
# Processing Record 42 of Set 11 | mehamn
# Processing Record 43 of Set 11 | gongzhuling
# Processing Record 44 of Set 11 | gorontalo
# Processing Record 45 of Set 11 | nador
# Processing Record 46 of Set 11 | margate
# Processing Record 47 of Set 11 | salalah
# Processing Record 48 of Set 11 | amancio
# City not found. Skipping...
# Processing Record 49 of Set 11 | elk plain
# Processing Record 50 of Set 11 | ammon
# Processing Record 1 of Set 12 | gorin
# Processing Record 2 of Set 12 | diamantino
# Processing Record 3 of Set 12 | cheremnoye
# Processing Record 4 of Set 12 | shkotovo-26
# City not found. Skipping...
# Processing Record 5 of Set 12 | cockburn town
# Processing Record 6 of Set 12 | san bartolome de tirajana
# Processing Record 7 of Set 12 | astoria
# Processing Record 8 of Set 12 | port moresby
# Processing Record 9 of Set 12 | kamenka
# Processing Record 10 of Set 12 | dong hoi
# Processing Record 11 of Set 12 | ayacucho
# Processing Record 12 of Set 12 | linares
# Processing Record 13 of Set 12 | tabory
# Processing Record 14 of Set 12 | shaartuz
# City not found. Skipping...
# Processing Record 15 of Set 12 | isangel
# Processing Record 16 of Set 12 | port keats
# Processing Record 17 of Set 12 | makubetsu
# Processing Record 18 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 12 | stuttgart
# Processing Record 20 of Set 12 | beberibe
# Processing Record 21 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 12 | petrokamenskoye
# Processing Record 23 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 12 | yilan
# Processing Record 25 of Set 12 | fare
# Processing Record 26 of Set 12 | udachnyy
# Processing Record 27 of Set 12 | carbonia
# Processing Record 28 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 12 | pangai
# Processing Record 30 of Set 12 | mareeba
# Processing Record 31 of Set 12 | nuristan
# Processing Record 32 of Set 12 | namibe
# Processing Record 33 of Set 12 | palmerston
# Processing Record 34 of Set 12 | black forest
# Processing Record 35 of Set 12 | shache
# Processing Record 36 of Set 12 | anadyr
# Processing Record 37 of Set 12 | mayskiy
# Processing Record 38 of Set 12 | kontagora
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | oranjemund
# Processing Record 41 of Set 12 | belyy yar
# Processing Record 42 of Set 12 | alyangula
# Processing Record 43 of Set 12 | wala
# Processing Record 44 of Set 12 | caxito
# Processing Record 45 of Set 12 | bonthe
# Processing Record 46 of Set 12 | jiangyou
# Processing Record 47 of Set 12 | nyurba
# Processing Record 48 of Set 12 | whitianga
# Processing Record 49 of Set 12 | brae
# Processing Record 50 of Set 12 | tahe
# Processing Record 1 of Set 13 | sao desiderio
# Processing Record 2 of Set 13 | barra patuca
# Processing Record 3 of Set 13 | maumere
# Processing Record 4 of Set 13 | kalmunai
# Processing Record 5 of Set 13 | bastia
# Processing Record 6 of Set 13 | harper
# Processing Record 7 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 13 | zhigansk
# Processing Record 9 of Set 13 | half moon bay
# Processing Record 10 of Set 13 | syasstroy
# Processing Record 11 of Set 13 | rojhan
# Processing Record 12 of Set 13 | bakchar
# Processing Record 13 of Set 13 | rabo de peixe
# Processing Record 14 of Set 13 | khartoum
# Processing Record 15 of Set 13 | galle
# Processing Record 16 of Set 13 | ambilobe
# Processing Record 17 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 13 | two rivers
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | oswego
# Processing Record 21 of Set 13 | boguchany
# Processing Record 22 of Set 13 | whitecourt
# Processing Record 23 of Set 13 | salisbury
# Processing Record 24 of Set 13 | guider
# Processing Record 25 of Set 13 | fagersta
# Processing Record 26 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 13 | baherden
# Processing Record 28 of Set 13 | kenai
# Processing Record 29 of Set 13 | maymyo
# Processing Record 30 of Set 13 | arica
# Processing Record 31 of Set 13 | nova olinda do norte
# Processing Record 32 of Set 13 | lengshuitan
# Processing Record 33 of Set 13 | sao jose da coroa grande
# Processing Record 34 of Set 13 | rocha
# Processing Record 35 of Set 13 | canoa
# Processing Record 36 of Set 13 | virginia beach
# Processing Record 37 of Set 13 | fonte boa
# Processing Record 38 of Set 13 | dalvik
# Processing Record 39 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 13 | turan
# Processing Record 41 of Set 13 | hualmay
# Processing Record 42 of Set 13 | jaisalmer
# Processing Record 43 of Set 13 | durango
# Processing Record 44 of Set 13 | cap malheureux
# Processing Record 45 of Set 13 | karratha
# Processing Record 46 of Set 13 | vila franca do campo
# Processing Record 47 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 48 of Set 13 | magistralnyy
# Processing Record 49 of Set 13 | pershotravneve
# Processing Record 50 of Set 13 | say
# Processing Record 1 of Set 14 | calvinia
# Processing Record 2 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 14 | wajir
# Processing Record 4 of Set 14 | statesboro
# Processing Record 5 of Set 14 | smolenka
# Processing Record 6 of Set 14 | marquette
# Processing Record 7 of Set 14 | taga
# Processing Record 8 of Set 14 | sayansk
# Processing Record 9 of Set 14 | biu
# Processing Record 10 of Set 14 | kysyl-syr
# Processing Record 11 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 14 | gizo
# Processing Record 13 of Set 14 | debre tabor
# Processing Record 14 of Set 14 | urucara
# Processing Record 15 of Set 14 | mezen
# Processing Record 16 of Set 14 | balikpapan
# Processing Record 17 of Set 14 | aswan
# Processing Record 18 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 14 | belmonte
# Processing Record 20 of Set 14 | kloulklubed
# Processing Record 21 of Set 14 | bratsk
# Processing Record 22 of Set 14 | dingzhou
# Processing Record 23 of Set 14 | kavaratti
# Processing Record 24 of Set 14 | acajutla
# Processing Record 25 of Set 14 | machiques
# Processing Record 26 of Set 14 | kungurtug
# Processing Record 27 of Set 14 | amga
# Processing Record 28 of Set 14 | erzin
# Processing Record 29 of Set 14 | mayo
# Processing Record 30 of Set 14 | puerto del rosario
# Processing Record 31 of Set 14 | mattru
# Processing Record 32 of Set 14 | batsfjord
# Processing Record 33 of Set 14 | hirara
# Processing Record 34 of Set 14 | qasigiannguit
# Processing Record 35 of Set 14 | peniche
# Processing Record 36 of Set 14 | jalu
# Processing Record 37 of Set 14 | mercedes
# Processing Record 38 of Set 14 | borogontsy
# Processing Record 39 of Set 14 | maniitsoq
# Processing Record 40 of Set 14 | asau
# Processing Record 41 of Set 14 | darhan
# Processing Record 42 of Set 14 | new baltimore
# Processing Record 43 of Set 14 | ibra
# Processing Record 44 of Set 14 | shitkino
# Processing Record 45 of Set 14 | samarkand
# Processing Record 46 of Set 14 | balabac
# Processing Record 47 of Set 14 | lady lake
# Processing Record 48 of Set 14 | ufimskiy
# Processing Record 49 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 14 | lucapa
# Processing Record 1 of Set 15 | safaqis
# City not found. Skipping...
# Processing Record 2 of Set 15 | burns lake
# Processing Record 3 of Set 15 | whitehorse
# Processing Record 4 of Set 15 | huarmey
# Processing Record 5 of Set 15 | kryva
# Processing Record 6 of Set 15 | ternate
# Processing Record 7 of Set 15 | houston
# Processing Record 8 of Set 15 | negombo
# Processing Record 9 of Set 15 | chebarkul
# Processing Record 10 of Set 15 | port macquarie
# Processing Record 11 of Set 15 | bad neuenahr-ahrweiler
# Processing Record 12 of Set 15 | sept-iles
# Processing Record 13 of Set 15 | alta floresta
# Processing Record 14 of Set 15 | uchiza
# Processing Record 15 of Set 15 | hami
# Processing Record 16 of Set 15 | chimoio
# Processing Record 17 of Set 15 | panubigan
# Processing Record 18 of Set 15 | kedrovyy
# Processing Record 19 of Set 15 | huilong
# Processing Record 20 of Set 15 | manoharpur
# Processing Record 21 of Set 15 | tommot
# Processing Record 22 of Set 15 | ayr
# Processing Record 23 of Set 15 | prainha
# Processing Record 24 of Set 15 | centralia
# Processing Record 25 of Set 15 | campobasso
# Processing Record 26 of Set 15 | machilipatnam
# Processing Record 27 of Set 15 | nalut
# Processing Record 28 of Set 15 | sawtell
# Processing Record 29 of Set 15 | turayf
# Processing Record 30 of Set 15 | deer lake
# Processing Record 31 of Set 15 | moron
# Processing Record 32 of Set 15 | wilmington
# Processing Record 33 of Set 15 | byron bay
# Processing Record 34 of Set 15 | karasjok
# Processing Record 35 of Set 15 | we
# City not found. Skipping...
# Processing Record 36 of Set 15 | calama
# Processing Record 37 of Set 15 | hervey bay
# Processing Record 38 of Set 15 | burica
# City not found. Skipping...
# Processing Record 39 of Set 15 | atar
# Processing Record 40 of Set 15 | nuevo ideal
# Processing Record 41 of Set 15 | aksarka
# Processing Record 42 of Set 15 | tabanan
# Processing Record 43 of Set 15 | santa cecilia
# Processing Record 44 of Set 15 | jatiroto
# Processing Record 45 of Set 15 | batticaloa
# Processing Record 46 of Set 15 | pobe
# Processing Record 47 of Set 15 | yudong
# Processing Record 48 of Set 15 | chaman
# Processing Record 49 of Set 15 | yerbogachen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 685

# %%
# Convert the array of Dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Alice Springs      AU -23.7000  133.8833     93.99        36          74
# 1        Hithadhoo      MV  -0.6000   73.0833     81.99        76          35
# 2              Leh      IN  34.1667   77.5833      3.54        66           0
# 3          Iqaluit      CA  63.7506  -68.5145    -13.00        70           1
# 4   Krasnyy Chikoy      RU  50.3643  108.7512      8.82        90         100
# 5        Cape Town      ZA -33.9258   18.4232     70.00        94          75
# 6            Pisco      PE -13.7000  -76.2167     71.60        73           0
# 7    San Cristobal      VE   7.7669  -72.2250     63.48        76          35
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     76.71        84          38
# 9          Erenhot      CN  43.6475  111.9767     20.84        90           0
#
#    Wind Speed Current Description
# 0       13.80       broken clouds
# 1       12.93       moderate rain
# 2        1.59           clear sky
# 3       27.63                snow
# 4        2.84     overcast clouds
# 5        3.44       broken clouds
# 6        6.91           clear sky
# 7        1.54    scattered clouds
# 8       24.09    scattered clouds
# 9       20.09           clear sky

# %%
# Create the Output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
