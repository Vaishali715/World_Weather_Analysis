# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combination
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c69d4102d300cea33c9753ae66a20466

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | zhanakorgan
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | listvyanskiy
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | natal
# Processing Record 9 of Set 1 | bentiu
# Processing Record 10 of Set 1 | whitley bay
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | rudbar
# Processing Record 13 of Set 1 | ko samui
# Processing Record 14 of Set 1 | balsas
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 1 | calbuco
# Processing Record 18 of Set 1 | saint-georges
# Processing Record 19 of Set 1 | neiafu
# Processing Record 20 of Set 1 | mabaruma
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | kysyl-syr
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 1 | kon tum
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | korocha
# Processing Record 33 of Set 1 | vostok
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | sinnamary
# Processing Record 38 of Set 1 | havre-saint-pierre
# Processing Record 39 of Set 1 | kurtamysh
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | saint anthony
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | iroquois falls
# Processing Record 50 of Set 1 | itarema
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 2 | santa rosa
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | glen allen
# Processing Record 7 of Set 2 | chifeng
# Processing Record 8 of Set 2 | valdivia
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | magadan
# Processing Record 12 of Set 2 | nabire
# Processing Record 13 of Set 2 | broken hill
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | antalaha
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | pingzhuang
# Processing Record 18 of Set 2 | campobello di mazara
# Processing Record 19 of Set 2 | arlit
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | paranaiba
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | bilibino
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | kailua
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | port pirie
# Processing Record 32 of Set 2 | topeka
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | baoro
# Processing Record 36 of Set 2 | sola
# Processing Record 37 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | petroton
# City not found. Skipping...
# Processing Record 40 of Set 2 | sfantu gheorghe
# Processing Record 41 of Set 2 | marawi
# Processing Record 42 of Set 2 | siva
# Processing Record 43 of Set 2 | garowe
# Processing Record 44 of Set 2 | samarai
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | grindavik
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | great yarmouth
# Processing Record 1 of Set 3 | macklin
# Processing Record 2 of Set 3 | voyvozh
# Processing Record 3 of Set 3 | kraslava
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | arshan
# Processing Record 6 of Set 3 | mount gambier
# Processing Record 7 of Set 3 | merauke
# Processing Record 8 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | paamiut
# Processing Record 12 of Set 3 | constitucion
# Processing Record 13 of Set 3 | hami
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | bereda
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | vila velha
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | toamasina
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | shingu
# Processing Record 23 of Set 3 | whitefish
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | hargeysa
# Processing Record 31 of Set 3 | sambava
# Processing Record 32 of Set 3 | sabang
# Processing Record 33 of Set 3 | svetlaya
# Processing Record 34 of Set 3 | seoul
# Processing Record 35 of Set 3 | roald
# Processing Record 36 of Set 3 | chicama
# Processing Record 37 of Set 3 | zemio
# Processing Record 38 of Set 3 | gorin
# Processing Record 39 of Set 3 | mpika
# Processing Record 40 of Set 3 | bellinge
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | havoysund
# Processing Record 43 of Set 3 | jalu
# Processing Record 44 of Set 3 | chillan
# Processing Record 45 of Set 3 | yangjiang
# Processing Record 46 of Set 3 | buraydah
# Processing Record 47 of Set 3 | dutlwe
# Processing Record 48 of Set 3 | port-gentil
# Processing Record 49 of Set 3 | constantine
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | finspang
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | la asuncion
# Processing Record 8 of Set 4 | champerico
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | veraval
# Processing Record 13 of Set 4 | komsomolskiy
# Processing Record 14 of Set 4 | tula
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | tomatlan
# Processing Record 19 of Set 4 | olinda
# Processing Record 20 of Set 4 | bandarban
# Processing Record 21 of Set 4 | khatanga
# Processing Record 22 of Set 4 | cockburn town
# Processing Record 23 of Set 4 | jibuti
# Processing Record 24 of Set 4 | aitape
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 4 | kahului
# Processing Record 28 of Set 4 | havelock
# Processing Record 29 of Set 4 | boende
# Processing Record 30 of Set 4 | catuday
# Processing Record 31 of Set 4 | muyezerskiy
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | sao miguel do araguaia
# Processing Record 34 of Set 4 | mineiros
# Processing Record 35 of Set 4 | catamarca
# Processing Record 36 of Set 4 | vadso
# Processing Record 37 of Set 4 | zheleznodorozhnyy
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | kushmurun
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | tigre
# Processing Record 44 of Set 4 | skelleftea
# Processing Record 45 of Set 4 | dobryanka
# Processing Record 46 of Set 4 | port macquarie
# Processing Record 47 of Set 4 | takoradi
# Processing Record 48 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | port alfred
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | rocha
# Processing Record 3 of Set 5 | upernavik
# Processing Record 4 of Set 5 | shimoda
# Processing Record 5 of Set 5 | piney green
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | fortuna foothills
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | mineral wells
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | deep river
# Processing Record 15 of Set 5 | tecoanapa
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | talcahuano
# Processing Record 18 of Set 5 | sondrio
# Processing Record 19 of Set 5 | othonoi
# City not found. Skipping...
# Processing Record 20 of Set 5 | inuvik
# Processing Record 21 of Set 5 | dickinson
# Processing Record 22 of Set 5 | los llanos de aridane
# Processing Record 23 of Set 5 | alakurtti
# Processing Record 24 of Set 5 | paita
# Processing Record 25 of Set 5 | erenhot
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | tytuvenai
# Processing Record 28 of Set 5 | bull savanna
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | la brea
# Processing Record 31 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 5 | okha
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | sayyan
# Processing Record 37 of Set 5 | muli
# Processing Record 38 of Set 5 | wagar
# Processing Record 39 of Set 5 | calatayud
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 5 | middelburg
# Processing Record 44 of Set 5 | betsiamites
# Processing Record 45 of Set 5 | comodoro rivadavia
# Processing Record 46 of Set 5 | chegdomyn
# Processing Record 47 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 5 | te anau
# Processing Record 49 of Set 5 | fershampenuaz
# Processing Record 50 of Set 5 | keningau
# Processing Record 1 of Set 6 | poum
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | nur
# Processing Record 6 of Set 6 | januaria
# Processing Record 7 of Set 6 | wanaka
# Processing Record 8 of Set 6 | elliot lake
# Processing Record 9 of Set 6 | shuangcheng
# Processing Record 10 of Set 6 | slave lake
# Processing Record 11 of Set 6 | bestobe
# Processing Record 12 of Set 6 | balkhash
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | koch bihar
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | the valley
# Processing Record 17 of Set 6 | alta floresta
# Processing Record 18 of Set 6 | bonthe
# Processing Record 19 of Set 6 | fayaoue
# Processing Record 20 of Set 6 | kismayo
# Processing Record 21 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 6 | smithers
# Processing Record 23 of Set 6 | marevo
# Processing Record 24 of Set 6 | husavik
# Processing Record 25 of Set 6 | craig
# Processing Record 26 of Set 6 | castro
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | najran
# Processing Record 29 of Set 6 | saint-francois
# Processing Record 30 of Set 6 | newport beach
# Processing Record 31 of Set 6 | san quintin
# Processing Record 32 of Set 6 | barra da estiva
# Processing Record 33 of Set 6 | adrar
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | kalamakion
# City not found. Skipping...
# Processing Record 36 of Set 6 | dolzhanskaya
# Processing Record 37 of Set 6 | ust-tsilma
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | olafsvik
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | odweyne
# Processing Record 42 of Set 6 | port hardy
# Processing Record 43 of Set 6 | bolshiye kolpany
# City not found. Skipping...
# Processing Record 44 of Set 6 | williston
# Processing Record 45 of Set 6 | ljungby
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | general pico
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | seda
# Processing Record 50 of Set 6 | porto velho
# Processing Record 1 of Set 7 | muravlenko
# Processing Record 2 of Set 7 | pacific grove
# Processing Record 3 of Set 7 | sitniki
# Processing Record 4 of Set 7 | kushiro
# Processing Record 5 of Set 7 | bilma
# Processing Record 6 of Set 7 | lesosibirsk
# Processing Record 7 of Set 7 | soe
# Processing Record 8 of Set 7 | oranjemund
# Processing Record 9 of Set 7 | dicabisagan
# Processing Record 10 of Set 7 | ribeira grande
# Processing Record 11 of Set 7 | dauriya
# Processing Record 12 of Set 7 | norman wells
# Processing Record 13 of Set 7 | oktyabrskoye
# Processing Record 14 of Set 7 | bulqize
# Processing Record 15 of Set 7 | daltenganj
# Processing Record 16 of Set 7 | jeremie
# Processing Record 17 of Set 7 | angoche
# Processing Record 18 of Set 7 | sweetwater
# Processing Record 19 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 7 | beauchamps
# Processing Record 21 of Set 7 | roros
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | kathmandu
# Processing Record 24 of Set 7 | hay river
# Processing Record 25 of Set 7 | riviere-au-renard
# Processing Record 26 of Set 7 | abancay
# Processing Record 27 of Set 7 | bara
# Processing Record 28 of Set 7 | xai-xai
# Processing Record 29 of Set 7 | falmouth
# Processing Record 30 of Set 7 | zhigansk
# Processing Record 31 of Set 7 | henties bay
# Processing Record 32 of Set 7 | sisimiut
# Processing Record 33 of Set 7 | ushtobe
# Processing Record 34 of Set 7 | surt
# Processing Record 35 of Set 7 | pinega
# Processing Record 36 of Set 7 | laguna
# Processing Record 37 of Set 7 | mahon
# Processing Record 38 of Set 7 | kudahuvadhoo
# Processing Record 39 of Set 7 | riaba
# City not found. Skipping...
# Processing Record 40 of Set 7 | vilhena
# Processing Record 41 of Set 7 | capao bonito
# Processing Record 42 of Set 7 | airai
# Processing Record 43 of Set 7 | ketchikan
# Processing Record 44 of Set 7 | lavrentiya
# Processing Record 45 of Set 7 | noyabrsk
# Processing Record 46 of Set 7 | balkanabat
# Processing Record 47 of Set 7 | nuristan
# Processing Record 48 of Set 7 | westport
# Processing Record 49 of Set 7 | yankton
# Processing Record 50 of Set 7 | pustoshka
# Processing Record 1 of Set 8 | killybegs
# Processing Record 2 of Set 8 | boguchany
# Processing Record 3 of Set 8 | general cepeda
# Processing Record 4 of Set 8 | agadez
# Processing Record 5 of Set 8 | half moon bay
# Processing Record 6 of Set 8 | san jose
# Processing Record 7 of Set 8 | lasa
# Processing Record 8 of Set 8 | luanda
# Processing Record 9 of Set 8 | svetlogorsk
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | darnah
# Processing Record 12 of Set 8 | codrington
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | mpulungu
# Processing Record 15 of Set 8 | coaticook
# Processing Record 16 of Set 8 | sao miguel do tapuio
# Processing Record 17 of Set 8 | sur
# Processing Record 18 of Set 8 | sorland
# Processing Record 19 of Set 8 | bow island
# Processing Record 20 of Set 8 | mecca
# Processing Record 21 of Set 8 | wad madani
# Processing Record 22 of Set 8 | yinchuan
# Processing Record 23 of Set 8 | kieta
# Processing Record 24 of Set 8 | khasan
# Processing Record 25 of Set 8 | mnogovershinnyy
# Processing Record 26 of Set 8 | ulladulla
# Processing Record 27 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | eureka
# Processing Record 30 of Set 8 | kyren
# Processing Record 31 of Set 8 | brainerd
# Processing Record 32 of Set 8 | chikoy
# City not found. Skipping...
# Processing Record 33 of Set 8 | deoria
# Processing Record 34 of Set 8 | young
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | gumdag
# Processing Record 37 of Set 8 | togitsu
# Processing Record 38 of Set 8 | vestmanna
# Processing Record 39 of Set 8 | bata
# Processing Record 40 of Set 8 | wattegama
# Processing Record 41 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 8 | lewistown
# Processing Record 43 of Set 8 | guider
# Processing Record 44 of Set 8 | mitu
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | queanbeyan
# Processing Record 47 of Set 8 | trairi
# Processing Record 48 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 8 | seymchan
# Processing Record 50 of Set 8 | kenai
# Processing Record 1 of Set 9 | novo aripuana
# Processing Record 2 of Set 9 | hualmay
# Processing Record 3 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 4 of Set 9 | narsaq
# Processing Record 5 of Set 9 | jimo
# Processing Record 6 of Set 9 | snyder
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | matiari
# Processing Record 9 of Set 9 | srandakan
# Processing Record 10 of Set 9 | nalut
# Processing Record 11 of Set 9 | deputatskiy
# Processing Record 12 of Set 9 | turbat
# Processing Record 13 of Set 9 | planaltina
# Processing Record 14 of Set 9 | mwingi
# Processing Record 15 of Set 9 | caruray
# Processing Record 16 of Set 9 | griffith
# Processing Record 17 of Set 9 | sri aman
# Processing Record 18 of Set 9 | margate
# Processing Record 19 of Set 9 | lichuan
# Processing Record 20 of Set 9 | sao joao da barra
# Processing Record 21 of Set 9 | filadelfia
# Processing Record 22 of Set 9 | san luis
# Processing Record 23 of Set 9 | esperantinopolis
# Processing Record 24 of Set 9 | santa cruz
# Processing Record 25 of Set 9 | saint george
# Processing Record 26 of Set 9 | sheridan
# Processing Record 27 of Set 9 | tiksi
# Processing Record 28 of Set 9 | sorata
# Processing Record 29 of Set 9 | santa pola
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | riyadh
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | okato
# Processing Record 34 of Set 9 | port hedland
# Processing Record 35 of Set 9 | gazli
# Processing Record 36 of Set 9 | provideniya
# Processing Record 37 of Set 9 | alghero
# Processing Record 38 of Set 9 | porto novo
# Processing Record 39 of Set 9 | atbasar
# Processing Record 40 of Set 9 | tazmalt
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | mutis
# Processing Record 43 of Set 9 | dera din panah
# City not found. Skipping...
# Processing Record 44 of Set 9 | khorixas
# Processing Record 45 of Set 9 | fort stewart
# Processing Record 46 of Set 9 | tarakan
# Processing Record 47 of Set 9 | ancud
# Processing Record 48 of Set 9 | quesnel
# Processing Record 49 of Set 9 | mackay
# Processing Record 50 of Set 9 | palaikastron
# Processing Record 1 of Set 10 | medzilaborce
# Processing Record 2 of Set 10 | warmbad
# Processing Record 3 of Set 10 | thinadhoo
# Processing Record 4 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 10 | lima
# Processing Record 6 of Set 10 | yeppoon
# Processing Record 7 of Set 10 | peniche
# Processing Record 8 of Set 10 | osorio
# Processing Record 9 of Set 10 | nishihara
# Processing Record 10 of Set 10 | pauini
# Processing Record 11 of Set 10 | monastyrshchina
# Processing Record 12 of Set 10 | belmonte
# Processing Record 13 of Set 10 | bemidji
# Processing Record 14 of Set 10 | pacifica
# Processing Record 15 of Set 10 | cidreira
# Processing Record 16 of Set 10 | torbat-e jam
# Processing Record 17 of Set 10 | luangwa
# Processing Record 18 of Set 10 | necochea
# Processing Record 19 of Set 10 | matagami
# Processing Record 20 of Set 10 | batavia
# Processing Record 21 of Set 10 | kinsale
# Processing Record 22 of Set 10 | witrivier
# City not found. Skipping...
# Processing Record 23 of Set 10 | maceio
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | oil city
# Processing Record 26 of Set 10 | ritchie
# Processing Record 27 of Set 10 | sitka
# Processing Record 28 of Set 10 | faya
# Processing Record 29 of Set 10 | naze
# Processing Record 30 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 10 | beberibe
# Processing Record 32 of Set 10 | kawalu
# Processing Record 33 of Set 10 | katherine
# Processing Record 34 of Set 10 | labuhan
# Processing Record 35 of Set 10 | ucluelet
# Processing Record 36 of Set 10 | la paz
# Processing Record 37 of Set 10 | panguipulli
# Processing Record 38 of Set 10 | khani
# Processing Record 39 of Set 10 | nantucket
# Processing Record 40 of Set 10 | toloa adentro
# City not found. Skipping...
# Processing Record 41 of Set 10 | pijijiapan
# Processing Record 42 of Set 10 | haines junction
# Processing Record 43 of Set 10 | isangel
# Processing Record 44 of Set 10 | harper
# Processing Record 45 of Set 10 | sampit
# Processing Record 46 of Set 10 | hommersak
# Processing Record 47 of Set 10 | malanje
# Processing Record 48 of Set 10 | fare
# Processing Record 49 of Set 10 | neryungri
# Processing Record 50 of Set 10 | puerto ayacucho
# Processing Record 1 of Set 11 | padang
# Processing Record 2 of Set 11 | salalah
# Processing Record 3 of Set 11 | borogontsy
# Processing Record 4 of Set 11 | chapais
# Processing Record 5 of Set 11 | liverpool
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | dargaville
# Processing Record 9 of Set 11 | nouadhibou
# Processing Record 10 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 11 of Set 11 | lixourion
# Processing Record 12 of Set 11 | velykyy burluk
# Processing Record 13 of Set 11 | zhangye
# Processing Record 14 of Set 11 | ambon
# Processing Record 15 of Set 11 | dzhubga
# Processing Record 16 of Set 11 | mahibadhoo
# Processing Record 17 of Set 11 | ambilobe
# Processing Record 18 of Set 11 | la salle
# Processing Record 19 of Set 11 | mitsamiouli
# Processing Record 20 of Set 11 | palauig
# Processing Record 21 of Set 11 | grand gaube
# Processing Record 22 of Set 11 | santa maria
# Processing Record 23 of Set 11 | cruz alta
# Processing Record 24 of Set 11 | schwaigern
# Processing Record 25 of Set 11 | pitea
# Processing Record 26 of Set 11 | shu
# Processing Record 27 of Set 11 | aklavik
# Processing Record 28 of Set 11 | tudela
# Processing Record 29 of Set 11 | homer
# Processing Record 30 of Set 11 | fort-shevchenko
# Processing Record 31 of Set 11 | sakakah
# Processing Record 32 of Set 11 | teguldet
# Processing Record 33 of Set 11 | lagos
# Processing Record 34 of Set 11 | sao miguel do iguacu
# Processing Record 35 of Set 11 | pevek
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | severo-kurilsk
# Processing Record 38 of Set 11 | chinsali
# Processing Record 39 of Set 11 | baculin
# Processing Record 40 of Set 11 | copiapo
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | tuatapere
# Processing Record 43 of Set 11 | tshela
# Processing Record 44 of Set 11 | sapa
# Processing Record 45 of Set 11 | itaituba
# Processing Record 46 of Set 11 | chaplynka
# Processing Record 47 of Set 11 | asfi
# Processing Record 48 of Set 11 | kaseda
# Processing Record 49 of Set 11 | panjakent
# Processing Record 50 of Set 11 | vardo
# Processing Record 1 of Set 12 | royal palm beach
# Processing Record 2 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 12 | sao gabriel da cachoeira
# Processing Record 4 of Set 12 | balad
# Processing Record 5 of Set 12 | porto-vecchio
# Processing Record 6 of Set 12 | south lake tahoe
# Processing Record 7 of Set 12 | canitas
# City not found. Skipping...
# Processing Record 8 of Set 12 | ust-omchug
# Processing Record 9 of Set 12 | pisco
# Processing Record 10 of Set 12 | zheshart
# Processing Record 11 of Set 12 | kralendijk
# Processing Record 12 of Set 12 | aberdeen
# Processing Record 13 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 12 | richmond
# Processing Record 15 of Set 12 | camacupa
# Processing Record 16 of Set 12 | kilindoni
# Processing Record 17 of Set 12 | dali
# Processing Record 18 of Set 12 | ziro
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | chadiza
# Processing Record 21 of Set 12 | narsingi
# Processing Record 22 of Set 12 | martinsville
# Processing Record 23 of Set 12 | portland
# Processing Record 24 of Set 12 | bardiyah
# Processing Record 25 of Set 12 | plavinas
# Processing Record 26 of Set 12 | safaga
# Processing Record 27 of Set 12 | erdaojiang
# Processing Record 28 of Set 12 | noumea
# Processing Record 29 of Set 12 | ndele
# Processing Record 30 of Set 12 | mumford
# Processing Record 31 of Set 12 | chigorodo
# Processing Record 32 of Set 12 | kokkola
# Processing Record 33 of Set 12 | makushino
# Processing Record 34 of Set 12 | ziarat
# Processing Record 35 of Set 12 | lahan
# Processing Record 36 of Set 12 | syedove
# Processing Record 37 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 12 | makakilo city
# Processing Record 39 of Set 12 | antofagasta
# Processing Record 40 of Set 12 | murray bridge
# Processing Record 41 of Set 12 | kloulklubed
# Processing Record 42 of Set 12 | ejido
# Processing Record 43 of Set 12 | aksarka
# Processing Record 44 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 12 | kungurtug
# Processing Record 47 of Set 12 | alekseyevka
# Processing Record 48 of Set 12 | guerrero negro
# Processing Record 49 of Set 12 | gizo
# Processing Record 50 of Set 12 | karsun
# Processing Record 1 of Set 13 | zatoka
# Processing Record 2 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 3 of Set 13 | nome
# Processing Record 4 of Set 13 | neuquen
# Processing Record 5 of Set 13 | benghazi
# Processing Record 6 of Set 13 | mananjary
# Processing Record 7 of Set 13 | bathsheba
# Processing Record 8 of Set 13 | goderich
# Processing Record 9 of Set 13 | harpalpur
# Processing Record 10 of Set 13 | yarada
# Processing Record 11 of Set 13 | karratha
# Processing Record 12 of Set 13 | douglas
# Processing Record 13 of Set 13 | raton
# Processing Record 14 of Set 13 | nizhniy kuranakh
# Processing Record 15 of Set 13 | hullhorst
# City not found. Skipping...
# Processing Record 16 of Set 13 | qui nhon
# Processing Record 17 of Set 13 | dukat
# Processing Record 18 of Set 13 | maniwaki
# Processing Record 19 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 20 of Set 13 | hashtrud
# Processing Record 21 of Set 13 | ambovombe
# Processing Record 22 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | pervomayskiy
# Processing Record 24 of Set 13 | castro marim
# Processing Record 25 of Set 13 | campana
# Processing Record 26 of Set 13 | guymon
# Processing Record 27 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 13 | point fortin
# Processing Record 29 of Set 13 | udachnyy
# Processing Record 30 of Set 13 | bucak
# Processing Record 31 of Set 13 | pandamatenga
# Processing Record 32 of Set 13 | avera
# Processing Record 33 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 13 | seidu
# Processing Record 35 of Set 13 | poway
# Processing Record 36 of Set 13 | orlik
# Processing Record 37 of Set 13 | marsabit
# Processing Record 38 of Set 13 | namatanai
# Processing Record 39 of Set 13 | alice springs
# Processing Record 40 of Set 13 | bubaque
# Processing Record 41 of Set 13 | banjar
# Processing Record 42 of Set 13 | yuanping
# Processing Record 43 of Set 13 | cayenne
# Processing Record 44 of Set 13 | omsukchan
# Processing Record 45 of Set 13 | conakry
# Processing Record 46 of Set 13 | charters towers
# Processing Record 47 of Set 13 | nyurba
# Processing Record 48 of Set 13 | ballina
# Processing Record 49 of Set 13 | puerto carreno
# Processing Record 50 of Set 13 | taylor
# Processing Record 1 of Set 14 | tuy hoa
# Processing Record 2 of Set 14 | raga
# Processing Record 3 of Set 14 | cap malheureux
# Processing Record 4 of Set 14 | matara
# Processing Record 5 of Set 14 | sakaiminato
# Processing Record 6 of Set 14 | along
# Processing Record 7 of Set 14 | cruzeiro do oeste
# Processing Record 8 of Set 14 | lanzhou
# Processing Record 9 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 14 | hede
# Processing Record 11 of Set 14 | whitianga
# Processing Record 12 of Set 14 | zionsville
# Processing Record 13 of Set 14 | somerset east
# Processing Record 14 of Set 14 | dunedin
# Processing Record 15 of Set 14 | khvoynaya
# Processing Record 16 of Set 14 | pafos
# Processing Record 17 of Set 14 | senno
# Processing Record 18 of Set 14 | brenes
# Processing Record 19 of Set 14 | gondanglegi
# Processing Record 20 of Set 14 | mogadishu
# Processing Record 21 of Set 14 | havre
# Processing Record 22 of Set 14 | yumen
# Processing Record 23 of Set 14 | xining
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | rock hill
# Processing Record 26 of Set 14 | benjamin hill
# Processing Record 27 of Set 14 | aguimes
# Processing Record 28 of Set 14 | sucha beskidzka
# Processing Record 29 of Set 14 | meulaboh
# Processing Record 30 of Set 14 | juazeiro
# Processing Record 31 of Set 14 | ranong
# Processing Record 32 of Set 14 | paithan
# Processing Record 33 of Set 14 | goundam
# Processing Record 34 of Set 14 | salvador
# Processing Record 35 of Set 14 | pudem
# Processing Record 36 of Set 14 | ha tinh
# Processing Record 37 of Set 14 | maniitsoq
# Processing Record 38 of Set 14 | bandarbeyla
# Processing Record 39 of Set 14 | liepaja
# Processing Record 40 of Set 14 | yazman
# Processing Record 41 of Set 14 | newport
# Processing Record 42 of Set 14 | proletariy
# Processing Record 43 of Set 14 | kajaani
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | odessa
# Processing Record 46 of Set 14 | usinsk
# Processing Record 47 of Set 14 | barreirinha
# Processing Record 48 of Set 14 | tupelo
# Processing Record 49 of Set 14 | monrovia
# Processing Record 50 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 15 | royal leamington spa
# Processing Record 2 of Set 15 | cabra
# Processing Record 3 of Set 15 | gonbad-e qabus
# Processing Record 4 of Set 15 | arman
# Processing Record 5 of Set 15 | srednekolymsk
# Processing Record 6 of Set 15 | calvinia
# Processing Record 7 of Set 15 | shenjiamen
# Processing Record 8 of Set 15 | goma
# Processing Record 9 of Set 15 | buala
# Processing Record 10 of Set 15 | celestun
# Processing Record 11 of Set 15 | yerbogachen
# Processing Record 12 of Set 15 | beyneu
# Processing Record 13 of Set 15 | lishui
# Processing Record 14 of Set 15 | pangkalanbuun
# Processing Record 15 of Set 15 | barcelos
# Processing Record 16 of Set 15 | oga
# Processing Record 17 of Set 15 | jiuquan
# Processing Record 18 of Set 15 | nelson bay
# Processing Record 19 of Set 15 | ewa beach
# Processing Record 20 of Set 15 | kankaanpaa
# Processing Record 21 of Set 15 | cape canaveral
# Processing Record 22 of Set 15 | alipur duar
# City not found. Skipping...
# Processing Record 23 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 15 | innisfail
# Processing Record 25 of Set 15 | nemuro
# Processing Record 26 of Set 15 | povazska bystrica
# Processing Record 27 of Set 15 | nicoya
# Processing Record 28 of Set 15 | mangan
# Processing Record 29 of Set 15 | azrow
# City not found. Skipping...
# Processing Record 30 of Set 15 | cap-aux-meules
# Processing Record 31 of Set 15 | san policarpo
# Processing Record 32 of Set 15 | koumac
# Processing Record 33 of Set 15 | lufilufi
# Processing Record 34 of Set 15 | shelton
# Processing Record 35 of Set 15 | tazovskiy
# Processing Record 36 of Set 15 | kabinda
# Processing Record 37 of Set 15 | abalak
# Processing Record 38 of Set 15 | hit
# Processing Record 39 of Set 15 | parana
# Processing Record 40 of Set 15 | azangaro
# Processing Record 41 of Set 15 | valparaiso
# Processing Record 42 of Set 15 | benalla
# Processing Record 43 of Set 15 | ahipara
# Processing Record 44 of Set 15 | tocopilla
# Processing Record 45 of Set 15 | gamba
# Processing Record 46 of Set 15 | kingisepp
# Processing Record 47 of Set 15 | ishim
# Processing Record 48 of Set 15 | mukhen
# Processing Record 49 of Set 15 | ishcherskaya
# Processing Record 50 of Set 15 | korop
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of Dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Katsuura      JP  35.1333  140.3000     46.40        31          20
# 1   Zhanakorgan      KZ  43.9098   67.2495     28.06        77          78
# 2  Ponta Do Sol      PT  32.6667  -17.1000     57.99        76          11
# 3        Faanui      PF -16.4833 -151.7500     81.00        67         100
# 4      Victoria      HK  22.2855  114.1577     69.01        63           0
# 5  Listvyanskiy      RU  54.4399   83.4984      8.71        96         100
# 6         Lagoa      PT  39.0500  -27.9833     59.70        82          97
# 7         Natal      BR  -5.7950  -35.2094     78.80        83          40
# 8        Bentiu      SS   9.2333   29.8333     68.25        21          38
# 9   Whitley Bay      GB  55.0397   -1.4471     37.99        87          75
#
#    Wind Speed Current Description
# 0       13.80          few clouds
# 1        7.29       broken clouds
# 2        3.00          few clouds
# 3        4.09     overcast clouds
# 4        1.99           clear sky
# 5        7.78     overcast clouds
# 6       19.08     overcast clouds
# 7        8.05    scattered clouds
# 8        5.44    scattered clouds
# 9        5.75       broken clouds

# %%
# Create the Output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
